# %% [markdown]
# # Process multiple stocks

# %%
import sys
sys.path.append("../code")

from data import Data
from graph import Graph

# %%
API_KEY = "SEOC47M8VXQBHO41"
symbols = ["UBER", "MSFT", "DIS"]

# %%
class Handler:

    def __init__(self, key, symbols):
        """Initialize variables and instantiate Data and Graph objects
        """
        self.process(key, symbols)

    def process(self, key, symbols):
        """Process and visualize data
        """
        for symbol in symbols:
            stock = Data(key=key, symbol=symbol)
            stock.get_x()
            stock.get_mean()
            stock.get_low()
            stock.get_high()
            stock.get_sma()
            stock.get_ema()
            stock.description = stock.interpret_sma()
            stock.get_bollinger_band()
            # Create plots
            viz = Graph(stock.data, stock.x, symbol)
            viz.create()

# %%
h = Handler(key=API_KEY, symbols=symbols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ea547fcf0808> in <module>
# ----> 1 h = Handler(key=API_KEY, symbols=symbols)
#
# <ipython-input-3-8ccfd280a2e3> in __init__(self, key, symbols)
#       4         """Initialize variables and instantiate Data and Graph objects
#       5         """
# ----> 6         self.process(key, symbols)
#       7
#       8     def process(self, key, symbols):
#
# <ipython-input-3-8ccfd280a2e3> in process(self, key, symbols)
#      10         """
#      11         for symbol in symbols:
# ---> 12             stock = Data(key=key, symbol=symbol)
#      13             stock.get_x()
#      14             stock.get_mean()
#
# ~/OneDrive/code/data_science/data_analytics/stocks/code/data.py in __init__(self, key, symbol)
#      20         self.symbol = symbol
#      21         self.timeseries = TimeSeries(key=self.API_KEY, output_format="pandas")
# ---> 22         self.fetch()
#      23
#      24     def fetch(self):
#
# ~/OneDrive/code/data_science/data_analytics/stocks/code/data.py in fetch(self)
#      25         """Fetch data from TimeSeries object
#      26         """
# ---> 27         self.data, self.meta = self.timeseries.get_daily(
#      28             symbol=self.symbol, outputsize="compact")
#      29         self.data = self.data.sort_index()
#
# ~/.local/lib/python3.8/site-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     216         @wraps(func)
#     217         def _format_wrapper(self, *args, **kwargs):
# --> 218             call_response, data_key, meta_data_key = func(
#     219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#
# ~/.local/lib/python3.8/site-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#     162
#
# ~/.local/lib/python3.8/site-packages/alpha_vantage/alphavantage.py in _handle_api_call(self, url)
#     339                 raise ValueError(json_response["Information"])
#     340             elif "Note" in json_response and self.treat_info_as_error:
# --> 341                 raise ValueError(json_response["Note"])
#     342             return json_response
#     343         else:
#
# ValueError: Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
