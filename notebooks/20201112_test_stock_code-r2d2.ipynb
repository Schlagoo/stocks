# %% [markdown]
# # Test environment

# %%
import sys
sys.path.append("../code")

# %%
from data import Data
from graph import Graph

# %%
API_KEY = "SEOC47M8VXQBHO41"
symbols = ["UBER", "MSFT", "DIS"]
symbol = "UBER"

# %% [markdown]
# ### Process data

# %%
stock = Data(key=API_KEY, symbol=symbol)

# %%
stock.get_x()

# %%
stock.get_mean()

# %%
stock.get_low()

# %%
stock.get_high()

# %%
stock.get_sma()

# %%
stock.get_ema()

# %%
stock.get_bollinger_band()

# %%
levels = stock.get_fibonacci_retracement()

# %% [markdown]
# ### Visualize data

# %%
viz = Graph(stock.data, stock.x, symbol, levels)

# %%
viz.create()

# %% [markdown]
# # Technical indicators
#
# ### Golden cross/death cross

# %%
print("SMA 15 - EMA 100: " + stock.check_for_cross() + " cross")
# Out:
# SMA 15 - EMA 100: no cross

# %% [markdown]
# ### Price Cross over

# %%
sma50 = stock.data["4. close"].rolling(window=50).mean().tail(5).values
sma50
# Out:
# array([31.4906, 31.697 , 31.9408, 32.2148, 32.465 ])

# %%
print("SMA 50 crossing Close: " + stock.check_for_price_crossover())
# Out:
# SMA 50 crossing Close: no

# %%
levels[0]
# Out:
# 42.23

# %% [markdown]
# ### Predict time series

# %%
# TODO
